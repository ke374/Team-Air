# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# Optional: Set English font if needed
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams['axes.unicode_minus'] = False

# Load cleaned dataset
df = pd.read_excel("final_model_data_2019_2024.xlsx")

# Drop unnecessary columns (e.g., unnamed index columns)
df = df.loc[:, ~df.columns.str.contains("Unnamed")]

# Define features and target variable
features = ["TEMP", "DEWP", "SLP", "VISIB", "WDSP", "MXSPD", "PRCP"]
target = "PM2.5"

X = df[features]
y = df[target]

# Split into training and testing sets (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize and train linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluation metrics
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print("✅ Linear Regression Model Evaluation:")
print(f"MAE:  {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R²:   {r2:.2f}")

# Display regression coefficients
coef_df = pd.DataFrame({
    "Feature": features,
    "Coefficient": model.coef_
})
print("\n📊 Regression Coefficients:")
print(coef_df)

# Plot: Actual vs Predicted
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.6)
plt.plot([y.min(), y.max()], [y.min(), y.max()], '--', color='red')
plt.xlabel("Actual PM2.5")
plt.ylabel("Predicted PM2.5")
plt.title("Actual vs Predicted PM2.5 (Linear Regression)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ✅ Linear Regression Model Evaluation:
# MAE:  15.68
# RMSE: 22.52
# R²:   0.56
#
# 📊 Regression Coefficients:
#   Feature  Coefficient
# 0    TEMP     0.606586
# 1    DEWP    -0.764945
# 2     SLP     4.105712
# 3   VISIB   -27.422606
# 4    WDSP    -1.582693
# 5   MXSPD     0.181017
# 6    PRCP     0.018139

# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# Set font (optional: switch to English-friendly font if needed)
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams['axes.unicode_minus'] = False

# Read dataset
df = pd.read_excel("final_model_data_2019_2024.xlsx")

# Drop unnamed or invalid columns
df = df.loc[:, ~df.columns.str.contains("Unnamed")]

# Define features and target variable (PM10)
features = ["TEMP", "DEWP", "SLP", "VISIB", "WDSP", "MXSPD", "PRCP"]
target = "PM10"

X = df[features]
y = df[target]

# Split data into training (70%) and testing (30%) sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Evaluate model
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print("✅ Linear Regression Model Evaluation (Target: PM10):")
print(f"MAE:  {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R²:   {r2:.2f}")

# Regression coefficients
coef_df = pd.DataFrame({
    "Feature": features,
    "Coefficient": model.coef_
})
print("\n📊 Regression Coefficients:")
print(coef_df)

# Plot: Actual vs Predicted
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.6)

# Set axis limits to focus on main value range
plt.xlim(0, 500)
plt.ylim(0, 500)

# Add diagonal reference line
plt.plot([0, 500], [0, 500], '--', color='red')

plt.xlabel("Actual PM10")
plt.ylabel("Predicted PM10")
plt.title("Actual vs Predicted PM10 (Linear Regression)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ✅ Linear Regression Model Evaluation (Target: PM10):
# MAE:  31.94
# RMSE: 44.34
# R²:   0.16
#
# 📊 Regression Coefficients:
#   Feature  Coefficient
# 0    TEMP     2.845745
# 1    DEWP    -2.861770
# 2     SLP   -51.425837
# 3   VISIB   -44.940953
# 4    WDSP     2.705272
# 5   MXSPD    -0.593494
# 6    PRCP    -0.043573

# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# Optional: Set font for English display
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams['axes.unicode_minus'] = False

# Load dataset
df = pd.read_excel("final_model_data_2019_2024.xlsx")

# Remove unwanted columns (e.g., unnamed index columns)
df = df.loc[:, ~df.columns.str.contains("Unnamed")]

# Define features and target variable (AQI)
features = ["TEMP", "DEWP", "SLP", "VISIB", "WDSP", "MXSPD", "PRCP"]
target = "AQI"

X = df[features]
y = df[target]

# Split into training and testing sets (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize and train linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate model
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print("✅ Linear Regression Model Evaluation (Target: AQI):")
print(f"MAE:  {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R²:   {r2:.2f}")

# Display regression coefficients
coef_df = pd.DataFrame({
    "Feature": features,
    "Coefficient": model.coef_
})
print("\n📊 Regression Coefficients:")
print(coef_df)

# Visualization: Actual vs Predicted
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.6)

# Adjust axes to focus on typical AQI range
plt.xlim(0, 250)
plt.ylim(0, 250)
plt.plot([0, 250], [0, 250], '--', color='red')

plt.xlabel("Actual AQI")
plt.ylabel("Predicted AQI")
plt.title("Actual vs Predicted AQI (Linear Regression)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ✅ Linear Regression Model Evaluation (Target: AQI):
# MAE:  21.96
# RMSE: 30.87
# R²:   0.45
#
# 📊 Regression Coefficients:
#   Feature  Coefficient
# 0    TEMP     1.762647
# 1    DEWP    -1.720799
# 2     SLP   -14.295498
# 3   VISIB   -35.401213
# 4    WDSP    -1.422336
# 5   MXSPD     0.308273
# 6    PRCP    -0.009478

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Optional: Set English font
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams['axes.unicode_minus'] = False

# Load dataset
df = pd.read_excel("final_model_data_2019_2024.xlsx")
df = df.loc[:, ~df.columns.str.contains("Unnamed")]  # Remove unnecessary columns

# Set features and target
features = ["TEMP", "DEWP", "SLP", "VISIB", "WDSP", "MXSPD", "PRCP"]
target = "PM2.5"
X = df[features]
y = df[target]

# Split data (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train Random Forest Regressor
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Predict
y_pred = rf_model.predict(X_test)

# Evaluation
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print("✅ Random Forest Model Evaluation (Target: PM2.5):")
print(f"MAE:  {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R²:   {r2:.2f}")

# Plot: Actual vs Predicted
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.6)
plt.plot([y.min(), y.max()], [y.min(), y.max()], '--', color='red')
plt.xlabel("Actual PM2.5")
plt.ylabel("Predicted PM2.5")
plt.title("Actual vs Predicted PM2.5 (Random Forest)")
plt.grid(True)
plt.tight_layout()
plt.show()

# Feature importance
importances = rf_model.feature_importances_
feat_df = pd.DataFrame({'Feature': features, 'Importance': importances})
feat_df = feat_df.sort_values(by="Importance", ascending=True)

# Plot: Feature Importance
plt.figure(figsize=(8, 6))
sns.barplot(x="Importance", y="Feature", data=feat_df, palette="viridis")
plt.title("Feature Importance for PM2.5 Prediction (Random Forest)")
plt.xlabel("Importance Score")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()
# Out:
# ✅ Random Forest Model Evaluation (Target: PM2.5):
# MAE:  12.37
# RMSE: 18.73
# R²:   0.70
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_25072\1333722874.py:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Importance", y="Feature", data=feat_df, palette="viridis")

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Set English-compatible font
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams['axes.unicode_minus'] = False

# Load dataset
df = pd.read_excel("final_model_data_2019_2024.xlsx")
df = df.loc[:, ~df.columns.str.contains("Unnamed")]  # Remove unnamed columns

# Define features and target variable (PM10)
features = ["TEMP", "DEWP", "SLP", "VISIB", "WDSP", "MXSPD", "PRCP"]
target = "PM10"
X = df[features]
y = df[target]

# Split into training and testing sets (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train Random Forest Regressor
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Make predictions
y_pred = rf_model.predict(X_test)

# Evaluate model
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print("✅ Random Forest Model Evaluation (Target: PM10):")
print(f"MAE:  {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R²:   {r2:.2f}")

# Plot: Actual vs Predicted
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.6)
plt.plot([y.min(), y.max()], [y.min(), y.max()], '--', color='red')
plt.xlabel("Actual PM10")
plt.ylabel("Predicted PM10")
plt.title("Actual vs Predicted PM10 (Random Forest)")
plt.grid(True)
plt.tight_layout()
plt.show()

# Feature Importance
importances = rf_model.feature_importances_
feat_df = pd.DataFrame({'Feature': features, 'Importance': importances})
feat_df = feat_df.sort_values(by="Importance", ascending=True)

# Plot: Feature Importance
plt.figure(figsize=(8, 6))
sns.barplot(x="Importance", y="Feature", data=feat_df, palette="viridis")
plt.title("Feature Importance for PM10 Prediction (Random Forest)")
plt.xlabel("Importance Score")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()
# Out:
# ✅ Random Forest Model Evaluation (Target: PM10):
# MAE:  25.04
# RMSE: 42.73
# R²:   0.22
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_25072\3293934700.py:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Importance", y="Feature", data=feat_df, palette="viridis")

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Set English font (optional)
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams['axes.unicode_minus'] = False

# Load dataset
df = pd.read_excel("final_model_data_2019_2024.xlsx")
df = df.loc[:, ~df.columns.str.contains("Unnamed")]  # Remove unnamed columns

# Define features and target variable (AQI)
features = ["TEMP", "DEWP", "SLP", "VISIB", "WDSP", "MXSPD", "PRCP"]
target = "AQI"
X = df[features]
y = df[target]

# Split into training and testing sets (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train Random Forest Regressor
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Make predictions
y_pred = rf_model.predict(X_test)

# Evaluate model
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print("✅ Random Forest Model Evaluation (Target: AQI):")
print(f"MAE:  {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R²:   {r2:.2f}")

# Plot: Actual vs Predicted
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.6)
plt.plot([y.min(), y.max()], [y.min(), y.max()], '--', color='red')
plt.xlabel("Actual AQI")
plt.ylabel("Predicted AQI")
plt.title("Actual vs Predicted AQI (Random Forest)")
plt.grid(True)
plt.tight_layout()
plt.show()

# Feature Importance
importances = rf_model.feature_importances_
feat_df = pd.DataFrame({'Feature': features, 'Importance': importances})
feat_df = feat_df.sort_values(by="Importance", ascending=True)

# Plot: Feature Importance
plt.figure(figsize=(8, 6))
sns.barplot(x="Importance", y="Feature", data=feat_df, palette="viridis")
plt.title("Feature Importance for AQI Prediction (Random Forest)")
plt.xlabel("Importance Score")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()
# Out:
# ✅ Random Forest Model Evaluation (Target: AQI):
# MAE:  16.94
# RMSE: 26.34
# R²:   0.60
# C:\Users\Melissa\AppData\Local\Temp\ipykernel_25072\637140314.py:63: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Importance", y="Feature", data=feat_df, palette="viridis")

# %%
# 导入必要库
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# 读取 Excel 文件（请确保路径和文件名匹配）
df = pd.read_excel("final_model_data_2019_2024.xlsx")

# 删除无用列
df_clean = df.drop(columns=["date", "Unnamed: 8"])

# 特征和目标变量划分
X = df_clean.drop(columns=["PM2.5", "PM10", "AQI"])
y_pm25 = df_clean["PM2.5"]
y_pm10 = df_clean["PM10"]
y_aqi = df_clean["AQI"]

# 拆分训练集与测试集（同一个特征X拆三组目标）
X_train, X_test, y_train_pm25, y_test_pm25 = train_test_split(X, y_pm25, test_size=0.2, random_state=42)
_, _, y_train_pm10, y_test_pm10 = train_test_split(X, y_pm10, test_size=0.2, random_state=42)
_, _, y_train_aqi, y_test_aqi = train_test_split(X, y_aqi, test_size=0.2, random_state=42)

# %%
# 定义绘制残差图的函数
def plot_residuals(y_test, y_pred, label):
    residuals = y_test - y_pred
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x=y_pred, y=residuals, alpha=0.6)
    plt.axhline(0, linestyle='--', color='red', linewidth=1.2)
    plt.xlabel(f"Predicted {label}")
    plt.ylabel("Residual (Actual - Predicted)")
    plt.title(f"Residual Plot for {label} (Random Forest)")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
# PM2.5 模型和残差图
model_pm25 = RandomForestRegressor(random_state=42)
model_pm25.fit(X_train, y_train_pm25)
y_pred_pm25 = model_pm25.predict(X_test)
plot_residuals(y_test_pm25, y_pred_pm25, label="PM2.5")

# PM10 模型和残差图
model_pm10 = RandomForestRegressor(random_state=42)
model_pm10.fit(X_train, y_train_pm10)
y_pred_pm10 = model_pm10.predict(X_test)
plot_residuals(y_test_pm10, y_pred_pm10, label="PM10")

# AQI 模型和残差图
model_aqi = RandomForestRegressor(random_state=42)
model_aqi.fit(X_train, y_train_aqi)
y_pred_aqi = model_aqi.predict(X_test)
plot_residuals(y_test_aqi, y_pred_aqi, label="AQI")

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Load cleaned data
df = pd.read_excel("final_model_data_2019_2024.xlsx")
df = df.loc[:, ~df.columns.str.contains("Unnamed")]
df["date"] = pd.to_datetime(df["date"])
df = df.sort_values("date")

# Set features and target
features = ["TEMP", "DEWP", "SLP", "VISIB", "WDSP", "MXSPD", "PRCP"]
target = "PM2.5"
X = df[features]
y = df[target]

# Split into train/test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train Random Forest model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)

# Create result DataFrame with corresponding dates
results_df = pd.DataFrame({
    "date": df.loc[y_test.index, "date"].values,
    "Actual_PM2.5": y_test.values,
    "Predicted_PM2.5": y_pred
}).sort_values("date")

# Plot time series
plt.figure(figsize=(14, 6))
plt.plot(results_df["date"], results_df["Actual_PM2.5"], label="Actual PM2.5", color="blue")
plt.plot(results_df["date"], results_df["Predicted_PM2.5"], label="Predicted PM2.5 (RF)", color="orange", alpha=0.7)
plt.axhline(75, linestyle='--', color='red', linewidth=1.2, label="National Limit (75 μg/m³)")

plt.xlabel("Date")
plt.ylabel("PM2.5 (μg/m³)")
plt.title("PM2.5 Time Series with Random Forest Predictions and National Standard")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Load cleaned data
df = pd.read_excel("final_model_data_2019_2024.xlsx")
df = df.loc[:, ~df.columns.str.contains("Unnamed")]
df["date"] = pd.to_datetime(df["date"])
df = df.sort_values("date")

# Set features and target
features = ["TEMP", "DEWP", "SLP", "VISIB", "WDSP", "MXSPD", "PRCP"]
target = "PM10"
X = df[features]
y = df[target]

# Split into train/test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train Random Forest model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)

# Create result DataFrame with corresponding dates
results_df = pd.DataFrame({
    "date": df.loc[y_test.index, "date"].values,
    "Actual_PM10": y_test.values,
    "Predicted_PM10": y_pred
}).sort_values("date")

# Plot time series
plt.figure(figsize=(14, 6))
plt.plot(results_df["date"], results_df["Actual_PM10"], label="Actual PM10", color="blue")
plt.plot(results_df["date"], results_df["Predicted_PM10"], label="Predicted PM10 (RF)", color="orange", alpha=0.7)
plt.axhline(150, linestyle='--', color='red', linewidth=1.2, label="National Limit (150 μg/m³)")

plt.xlabel("Date")
plt.ylabel("PM10 (μg/m³)")
plt.title("PM10 Time Series with Random Forest Predictions and National Standard")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Load cleaned data
df = pd.read_excel("final_model_data_2019_2024.xlsx")
df = df.loc[:, ~df.columns.str.contains("Unnamed")]
df["date"] = pd.to_datetime(df["date"])
df = df.sort_values("date")

# Set features and target
features = ["TEMP", "DEWP", "SLP", "VISIB", "WDSP", "MXSPD", "PRCP"]
target = "AQI"
X = df[features]
y = df[target]

# Split into train/test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train Random Forest model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)

# Create result DataFrame with corresponding dates
results_df = pd.DataFrame({
    "date": df.loc[y_test.index, "date"].values,
    "Actual_AQI": y_test.values,
    "Predicted_AQI": y_pred
}).sort_values("date")

# Plot time series
plt.figure(figsize=(14, 6))
plt.plot(results_df["date"], results_df["Actual_AQI"], label="Actual AQI", color="blue")
plt.plot(results_df["date"], results_df["Predicted_AQI"], label="Predicted AQI (RF)", color="orange", alpha=0.7)
plt.axhline(100, linestyle='--', color='red', linewidth=1.2, label="Standard line (100)")

plt.xlabel("Date")
plt.ylabel("AQI (μg/m³)")
plt.title("AQI Time Series with Random Forest Predictions and National Standard")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
